# %% [markdown]
# 作業一

# %% [markdown]
# 請上 Kaggle, 在 Competitions 或 Dataset 中找一組競賽或資料並寫下：
# 資料：Stack Overflow Data
#
# 1.你選的這組資料為何重要：
# stack overflow 是IT人員重要的學習社群, 整理其相關的資訊可以更好的掌握各語言的發展.
# 在工作上選擇更適合自己的發展方向或更適合的工具.
#
# 2.資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)：
# 提供者為：archive.org.
#
# 3.蒐集而來的資料型態為何：
# 此資料是結構化資料.
#
# 4.這組資料想解決的問題如何評估：
# 這資料量相當大, 也有很多可以發想的問題, 例如我們可以在使用者中找到真正的IT高手.
# 或者找到近期崛起的程式語言等.

# %% [markdown]
# 作業二

# %% [raw]
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
#
# 1.核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)：
#   空車的時間，當司機在每趟載客之間的時間越長，收益的效益越低。
#   先假設司機在載到客人之後，收益是每半小時一百。
#   若一日在八趟短程，每趟花了半小時。收入為八百，但是，在每趟之間花了十五分鐘去找客人。
#   所以等於花了快六小時才賺到八百。
#   但是如果是在了兩趟長途，兩趟花了兩小時，收日依樣八百，每趟之間一樣花十五分鐘
#   所以等於花四小時就賺到八百。
#
#   也只是一個比較粗略的計算。但是可以見得司機只要花得越少時間去找客人就可以將業績提升。
#
# 2.資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)：
#   車的位置。有車的位置才可以確認車在哪裡接到客人，然後客人的目的地。
#   之後就可分析客人多在哪裡上車，也可能可以較為知道哪裡客人多為長途客人
#
#
# 3.蒐集而來的資料型態為何：
#    結構化
#
# 4.你要回答的問題，其如何評估 (tips：你的假設如何驗證)：
#    只要藉由位司機實際上的空車時間，就可以確認是否空車時間和收入成反比。

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,yb):
    mse=sum((y-yb)**2)/len(y)
    """
    
    請完成這個 Function 後往下執行
    """
    return mse

# %%
def mean_absolute_error(y,yb):
    mae=sum(((y-yb)**2)**(1/2))/len(y)
    """
    
    請完成這個 Function 後往下執行
    """
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 260.060
# The Mean absolute error is 12.918
